# %% [markdown]
# # External code
#
# Here we'll use external code packages to do things with Python.

# %% [markdown]
# The next example can be simply run

# %%
# first we import "pandas" with the shortened name "pd" (this just means we need to type less)
import pandas as pd

# now we use the function "read_csv()" from pandas to download a file with earthquake data in it
# we want to use this data so we assign it to a variable called df (short for dataframe, a pandas convention)
df = pd.read_csv('https://corgis-edu.github.io/corgis/datasets/csv/earthquakes/earthquakes.csv')

# to show it we got the data, lets print the first record
print(df.iloc[0])
# Out:
# id                                          nc72666881
# impact.gap                                       122.0
# impact.magnitude                                  1.43
# impact.significance                                 31
# location.depth                                   15.12
# location.distance                               0.1034
# location.full          13km E of Livermore, California
# location.latitude                            37.672333
# location.longitude                            -121.619
# location.name                               California
# time.day                                            27
# time.epoch                               1469593183550
# time.full                          2016-07-27 00:19:43
# time.hour                                            0
# time.minute                                         19
# time.month                                           7
# time.second                                         43
# time.year                                         2016
# Name: 0, dtype: object

# %% [markdown]
# We can use the `datetime` package to work with dates and times.
#
# Let's use it to find out what day of the week you were born on. Edit below and use the information on [this page](https://www.w3schools.com/python/python_datetime.asp) to print the day of the week for a date you choose.

# %%
# first setup our date
date = 22
month = 12
year = 1909

# now write your code to import the datetime package
import datetime


# now create a new datetime variable
# find an example here: https://www.w3schools.com/python/python_datetime.asp
# in the "Creating Date Objects" section
myBirthdate = datetime.datetime(year,month,date)

# now print out the day of the week
# find an example on the same web page in the strftime() method (strftime = string from time)
print(myBirthdate.strftime("%A"))
# Out:
# Wednesday

# %% [markdown]
# In the next exercise you'll need to install a package into the environment using `!pip install <packagename>`

# %%
# !pip install cartopy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting cartopy
#   Downloading Cartopy-0.23.0-cp310-cp310-win_amd64.whl.metadata (8.2 kB)
# Requirement already satisfied: numpy>=1.21 in c:\users\darow4074\appdata\roaming\python\python310\site-packages (from cartopy) (1.24.3)
# Requirement already satisfied: matplotlib>=3.5 in c:\users\darow4074\appdata\roaming\python\python310\site-packages (from cartopy) (3.8.0)
# Requirement already satisfied: shapely>=1.7 in c:\users\darow4074\appdata\roaming\python\python310\site-packages (from cartopy) (2.0.2)
# Requirement already satisfied: packaging>=20 in c:\users\darow4074\appdata\roaming\python\python310\site-packages (from cartopy) (23.1)
# Collecting pyshp>=2.3 (from cartopy)
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl.metadata (55 kB)
# Requirement already satisfied: pyproj>=3.3.1 in c:\users\darow4074\appdata\roaming\python\python310\site-packages (from cartopy) (3.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\darow4074\appdata\roaming\python\python310\site-packages (from matplotlib>=3.5->cartopy) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\darow4074\appdata\roaming\python\python310\site-packages (from matplotlib>=3.5->cartopy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\darow4074\appdata\roaming\python\python310\site-packages (from matplotlib>=3.5->cartopy) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\darow4074\appdata\roaming\python\python310\site-packages (from matplotlib>=3.5->cartopy) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\darow4074\appdata\roaming\python\python310\site-packages (from matplotlib>=3.5->cartopy) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\darow4074\appdata\roaming\python\python310\site-packages (from matplotlib>=3.5->cartopy) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\darow4074\appdata\roaming\python\python310\site-packages (from matplotlib>=3.5->cartopy) (2.8.2)
# Requirement already satisfied: certifi in c:\users\darow4074\appdata\roaming\python\python310\site-packages (from pyproj>=3.3.1->cartopy) (2023.5.7)
# Requirement already satisfied: six>=1.5 in c:\users\darow4074\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib>=3.5->cartopy) (1.16.0)
# Downloading Cartopy-0.23.0-cp310-cp310-win_amd64.whl (10.9 MB)
#    ---------------------------------------- 0.0/10.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.9 MB ? eta -:--:--
#     --------------------------------------- 0.3/10.9 MB ? eta -:--:--
#     --------------------------------------- 0.3/10.9 MB ? eta -:--:--
#    - -------------------------------------- 0.5/10.9 MB 932.9 kB/s eta 0:00:12
#    -- ------------------------------------- 0.8/10.9 MB 907.1 kB/s eta 0:00:12
#    --- ------------------------------------ 1.0/10.9 MB 915.5 kB/s eta 0:00:11
#    ---- ----------------------------------- 1.3/10.9 MB 987.4 kB/s eta 0:00:10
#    ---- ----------------------------------- 1.3/10.9 MB 987.4 kB/s eta 0:00:10
#    ----- ---------------------------------- 1.6/10.9 MB 964.5 kB/s eta 0:00:10
#    ------ --------------------------------- 1.8/10.9 MB 959.1 kB/s eta 0:00:10
#    ------- -------------------------------- 2.1/10.9 MB 995.1 kB/s eta 0:00:09
#    --------- ------------------------------ 2.6/10.9 MB 1.1 MB/s eta 0:00:08
#    ---------- ----------------------------- 2.9/10.9 MB 1.2 MB/s eta 0:00:07
#    ------------ --------------------------- 3.4/10.9 MB 1.3 MB/s eta 0:00:06
#    ------------- -------------------------- 3.7/10.9 MB 1.3 MB/s eta 0:00:06
#    -------------- ------------------------- 3.9/10.9 MB 1.3 MB/s eta 0:00:06
#    --------------- ------------------------ 4.2/10.9 MB 1.3 MB/s eta 0:00:06
#    ---------------- ----------------------- 4.5/10.9 MB 1.3 MB/s eta 0:00:06
#    ----------------- ---------------------- 4.7/10.9 MB 1.3 MB/s eta 0:00:05
#    ----------------- ---------------------- 4.7/10.9 MB 1.3 MB/s eta 0:00:05
#    ------------------- -------------------- 5.2/10.9 MB 1.3 MB/s eta 0:00:05
#    ------------------- -------------------- 5.2/10.9 MB 1.3 MB/s eta 0:00:05
#    -------------------- ------------------- 5.5/10.9 MB 1.2 MB/s eta 0:00:05
#    -------------------- ------------------- 5.5/10.9 MB 1.2 MB/s eta 0:00:05
#    --------------------- ------------------ 5.8/10.9 MB 1.2 MB/s eta 0:00:05
#    ---------------------- ----------------- 6.0/10.9 MB 1.1 MB/s eta 0:00:05
#    ---------------------- ----------------- 6.0/10.9 MB 1.1 MB/s eta 0:00:05
#    ---------------------- ----------------- 6.0/10.9 MB 1.1 MB/s eta 0:00:05
#    ----------------------- ---------------- 6.3/10.9 MB 1.1 MB/s eta 0:00:05
#    ------------------------ --------------- 6.6/10.9 MB 1.1 MB/s eta 0:00:05
#    ------------------------ --------------- 6.6/10.9 MB 1.1 MB/s eta 0:00:05
#    ------------------------- -------------- 6.8/10.9 MB 1.0 MB/s eta 0:00:04
#    ------------------------- -------------- 6.8/10.9 MB 1.0 MB/s eta 0:00:04
#    ------------------------- -------------- 6.8/10.9 MB 1.0 MB/s eta 0:00:04
#    ------------------------- -------------- 6.8/10.9 MB 1.0 MB/s eta 0:00:04
#    ------------------------- -------------- 7.1/10.9 MB 973.7 kB/s eta 0:00:04
#    ------------------------- -------------- 7.1/10.9 MB 973.7 kB/s eta 0:00:04
#    --------------------------- ------------ 7.6/10.9 MB 970.6 kB/s eta 0:00:04
#    ----------------------------- ---------- 8.1/10.9 MB 1.0 MB/s eta 0:00:03
#    ------------------------------ --------- 8.4/10.9 MB 1.0 MB/s eta 0:00:03
#    -------------------------------- ------- 8.9/10.9 MB 1.1 MB/s eta 0:00:02
#    ------------------------------------- -- 10.2/10.9 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 10.9/10.9 MB 1.2 MB/s eta 0:00:00
# Downloading pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
# Installing collected packages: pyshp, cartopy
# Successfully installed cartopy-0.23.0 pyshp-2.3.1

# %%
# the following code needs the package "cartopy" to be installed. Install the package then see what the output is.

import cartopy.crs as ccrs
import matplotlib.pyplot as plt

ax = plt.axes(projection=ccrs.PlateCarree())
ax.coastlines()

# Save the plot by calling plt.savefig() BEFORE plt.show()
plt.savefig('coastlines.pdf')
plt.savefig('coastlines.png')

plt.show()
